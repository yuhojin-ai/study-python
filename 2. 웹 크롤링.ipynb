# %% [markdown]
# ### 웹 크롤링
# 웹 크롤링은 데이터를 체계적으로 스캔하는 자동화된 프로세스입니다. 웹
# 페이지에 대한 정보를 색인화하고 저장하는 인터넷. Google, Bing, Yahoo와 같은 검색 엔진은 웹 크롤러를 사용하여 웹사이트에 대한 데이터를 수집하고 검색 색인을 구축합니다.
#
# 웹 크롤링 프로세스는 스파이더 또는 봇이라고도 하는 검색 엔진의 크롤러가 웹사이트를 만들고 그 콘텐츠를 분석합니다.
# 그런 다음 크롤러는 웹사이트의 링크를 따라 다른 페이지로 이동하며 크롤러가 웹사이트 및 링크된 웹사이트에서 가능한 많은 부분을 색인화할 때까지 프로세스가 계속됩니다.
#
# 웹 크롤러는 복잡한 알고리즘을 사용하여 정보를 식별하고 분류합니다.
# 페이지 제목, 메타 태그, 링크, 이미지 및 콘텐츠를 포함한 웹 페이지에 대한 정보.
# 그런 다음 이 정보는 검색 엔진에서 검색 결과를 생성하는 데 사용됩니다.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %%
browser = webdriver.Chrome()   # Chrome driver

# %%
browser.get('http://naver.com')

# %%
elem = browser.find_element(By.LINK_TEXT, '카페')    # 케페 찾아옴
print(elem)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="cc6a626d3ef85b4cb1c40365099b6dc4", element="f.8FD40FD2D7E3D884CAD5D767B1CBF285.d.752262496E9D42DF96418928119006C4.e.100")>

# %%
elem.get_attribute('href')
# Out:
# 'https://cafe.naver.com/'

# %%
elem.get_attribute('class')
# Out:
# 'link_service'

# %%
# 앞으로 가기
browser.forward()

# %%
# 새로이 고팀
browser.refresh()

# %%
elem = browser.find_element(By.ID, 'query')

# %%
elem.send_keys('이선희')

# %%
elem.send_keys(Keys.ENTER)

# %%
browser.back()

# %%
browser.get('http://naver.com')
elem = browser.find_element(By.ID, 'query')
elem.send_keys('이선희')
elem.send_keys(Keys.ENTER)
browser.back()
# 앞으로 가기
browser.forward()

# %%
elems = browser.find_elements(By.TAG_NAME, 'a')
for e in elems:
    tag = e.get_attribute('href')
    print(tag)
# Out:
# https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=%EC%9D%B4%EC%84%A0%ED%9D%AC&ackey=yutu8qgm#lnb
# https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=%EC%9D%B4%EC%84%A0%ED%9D%AC&ackey=yutu8qgm#content
# https://www.naver.com/
# https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=%EC%9D%B4%EC%84%A0%ED%9D%AC&ackey=yutu8qgm#
# https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=%EC%9D%B4%EC%84%A0%ED%9D%AC&ackey=yutu8qgm#
# https://search.naver.com/search.naver?ssc=tab.image.all&where=image&sm=tab_jum&query=%EC%9D%B4%EC%84%A0%ED%9D%AC
# https://search.naver.com/search.naver?ssc=tab.news.all&where=news&sm=tab_jum&query=%EC%9D%B4%EC%84%A0%ED%9D%AC
# https://search.naver.com/search.naver?ssc=tab.blog.all&sm=tab_jum&query=%EC%9D%B4%EC%84%A0%ED%9D%AC
# https://search.naver.com/search.naver?ssc=tab.cafe.all&sm=tab_jum&query=%EC%9D%B4%EC%84%A0%ED%9D%AC
# ...

# %%
# daum 사이트로 이동
browser.get('http://daum.net')

# %%
elem = browser.find_element(By.NAME, 'q')

# %%
elem.send_keys('이선희')

# %%
elem.clear()

# %%
elem.send_keys('이선희')

# %%
elem.send_keys(Keys.ENTER)

# %%
browser.back()

# %%
elem = browser.find_element(By.XPATH,'//*[@id="daumSearch"]/fieldset/div/div/button[2]')
elem.click()

# %%
elem = browser.find_element(By.XPATH, '/html/body/div[2]/header/div[2]/div[1]/ul/li[2]/a')
elem.click()

# %%
browser.save_screenshot('daum_home_page.png')
# Out:
# True

# %%
browser.page_source
# Out:
# '<html lang="ko" data-darktheme="false" style="zoom: 1;"><head>\n  <meta charset="utf-8">\n  <title>Daum</title>\n  <meta http-equiv="x-ua-compatible" content="IE=edge">\n  <meta property="og:url" content="https://www.daum.net/">\n  <meta property="og:type" content="website">\n  <meta property="og:title" content="Daum">\n  <meta http-equiv="Pragma" content="no-cache">\n  <meta http-equiv="Expires" content="-1">\n  <meta name="referrer" content="origin">\n  <meta name="viewport" content="width=device-width,minimum-scale=1,initial-scale=1">\n  <meta property="og:image" content="https://t1.daumcdn.net/top/favicon/20241223/daum_og.png">\n  <meta property="og:description" content="이용자 선택권을 강화한 뉴스, 세상의 모든 정보를 연결하는 검색. Daum에서 나의 관심 콘텐츠를 즐겨보세요.">\n  <meta name="description" content="이용자 선택권을 강화한 뉴스, 세상의 모든 정보를 연결하는 검색. Daum에서 나의 관심 콘텐츠를 즐겨보세요.">\n  <link href="https://t1.daumcdn.net/top/favicon/20241223/daum.ico" rel="shortcut icon">\n  <meta name="referrer" content="origin">\n  <link rel="s
# ...

# %%
# 브라우저 종료
browser.close()
browser.quit()

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
browser = webdriver.Chrome()

# %%
browser.get('https://www.w3schools.com/tags/tryit.asp?filename=tryhtml5_input_type_radio')

# %%
browser.switch_to.frame('iframeResult')

# %%
elem = browser.find_element(By.XPATH, '//*[@id="html"]')
elem.click()

# %%
elem = browser.find_element(By.XPATH, '//*[@id="age1"]')
elem.click()

# %%
browser.quit()

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
browser = webdriver.Chrome()
browser.get('https://www.w3schools.com/tags/tryit.asp?filename=tryhtml5_input_type_radio')
browser.switch_to.frame('iframeResult') # 프레임 전환
elem = browser.find_element(By.XPATH, '//*[@id="html"]')
if elem.is_selected() == False: # 라디오 버튼이 선택이 있느냐
    print("첫번째 라디오 버튼이 선택이 안되어 있으므로 선택하기 ")
    elem.click()
else:
    print("첫번째 라디오 버튼이 선택이 되어 있으므로 아무것도 안함")

elem = browser.find_element(By.XPATH, '//*[@id="age1"]')
if elem.is_selected() == False: # 라디오 버튼이 선택이 있느냐
    print("두번째 라디오 버튼이 선택이 안되어 있으므로 선택하기 ")
    elem.click()
else:
    print("두번째 라디오 버튼이 선택이 되어 있으므로 아무것도 안함")
# Out:
# 첫번째 라디오 버튼이 선택이 안되어 있으므로 선택하기
# 두번째 라디오 버튼이 선택이 안되어 있으므로 선택하기

# %%
browser.quit()

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
browser = webdriver.Chrome()

browser.get('https://www.w3schools.com/tags/tryit.asp?filename=tryhtml5_input_type_checkbox')

browser.switch_to.frame('iframeResult')

elem = browser.find_element(By.ID, 'vehicle1')

time.sleep(5)

if elem.is_selected() == False: # 라디오 버튼이 선택이 있느냐
    print(" 선택이 안되어 있으므로 선택")
    elem.click()
else:
    print("선택이 되어 있으므로 아무것도 안함")
# Out:
# 선택이 되어 있으므로 아무것도 안함

# %%
time.sleep(5)
if elem.is_selected() == False: # 라디오 버튼이 선택이 있느냐
    print(" 선택이 안되어 있으므로 선택")
    elem.click()
else:
    print("선택이 되어 있으므로 아무것도 안함")
# Out:
# 선택이 되어 있으므로 아무것도 안함

# %%
browser.quit()

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
browser = webdriver.Chrome()

browser.get('https://www.w3schools.com/tags/tryit.asp?filename=tryhtml_option')

browser.switch_to.frame('iframeResult')

# %%
elem = browser.find_element(By.XPATH, '//*[@id="cars"]/option[contains(text(), "Au")]')
elem.click()

# %%
value = elem.get_attribute('value')
print('4 번째 옵션의 value 값 : ', value)
# Out:
# 4 번째 옵션의 value 값 :  audi

# %%
time.sleep(5)
browser.quit()

# %% [markdown]
# ### Page Scroll

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
browser = webdriver.Chrome()

# %%
browser.get('https://shopping.naver.com/ns/home')
# //*[@id="input_text"]

# %%
elem = browser.find_element(By.XPATH, '//*[@id="input_text"]')
elem.send_keys('무선마우스')

time.sleep(2)

elem.send_keys(Keys.ENTER)

# %%
time.sleep(3)
# 스크롤
# 지정한 위치로 스크롤 내리기
# 모니터의 크기의 따라서 높이가 정해진다(1080)
browser.execute_script('window.scrollTo(0, 1080)')

# %%
time.sleep(3)
# 화면의 가장 알래로 스크롤 내리기
browser.execute_script('window.scrollTo(0, document.body.scrollHeight)')

# %%
time.sleep(3)
# 화면의 가장 위로 스크롤 내리기
browser.execute_script('window.scrollTo(0, 0)')

# %%
time.sleep(5)
browser.quit()
